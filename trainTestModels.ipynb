# %%
import os
import numpy as np
from collections import Counter
#from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import confusion_matrix
from sklearn.svm import LinearSVC
import pandas as pd

# %%
from sklearn.cross_validation import train_test_split

# %%
# third trail

def words_generator(fileobj):
    for line in fileobj:
        for word in line.split():
            yield word

def make_Dictionary(root_dir):
    word_count_dict={}
    emails_dirs = [os.path.join(root_dir,f) for f in os.listdir(root_dir)]    
    for emails_dir in emails_dirs:
        dirs = [os.path.join(emails_dir,f) for f in os.listdir(emails_dir)]
        for d in dirs:
            emails = [os.path.join(d,f) for f in os.listdir(d)]
            
            for mail in emails:
                file_name = mail.rsplit('/', 1)[-1]
                file_dict[file_name] = {}                    
                f = open(mail,"r")
                words = words_generator(f)
                for word in words:
                    if word.isalpha()==False:
                        continue                        
                    if word not in word_count_dict:
                          word_count_dict[word] = 0
                    word_count_dict[word]+= 1                    
    return word_count_dict

# %%
def find_most_frequent_words(word_count_dict):
    #word_freq_dict = {}
    df = pd.DataFrame(word_count_dict.items(), columns=['word', 'total_freq'])
    #df['total_freq'] = df['freq_values'].apply(lambda x: x.get('total'))
    print len(df)
    df = df.sort(['total_freq'],ascending=False).head(n=3000)
    return df['word'].tolist()

# %%
main_dir = "/home/datascience/Desktop/SpamFiltering/enronEmailData"

word_count_dict = make_Dictionary(main_dir)

freq_words = find_most_frequent_words(word_count_dict)

# %%
df = pd.read_csv('/home/datascience/Desktop/SpamFiltering/features.csv', sep='\t', lineterminator='\n',
                 na_values=['-'])

# %%
columns = list(df.columns.values)
words = columns[:]
words.remove("is_spam")
words.remove("file_name")

# %%
df_spam = pd.DataFrame()
df_spam["is_spam"] = df["is_spam"]
df.drop('is_spam', axis=1, inplace=True)

# %%
df.drop('file_name', axis=1, inplace=True)

# %%
df[pd.isnull(df).any(axis=1)]
# Out:
#        the  to  and  of   a  in  for  you  is  this  ...   georgia  confident  \
# 30     NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 31     NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 32     NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 33     NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 34     NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 35     NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 36     NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 37     NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 38     NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 39     NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 40     NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 41     NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 42     NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 43     NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 44     NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 45     NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 46     NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 47     NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 48     NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 49     NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 50     NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 51     NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 52     NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 53     NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 54     NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 55     NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 56     NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 57     NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 58     NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 59     NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# ...    ...  ..  ...  ..  ..  ..  ...  ...  ..   ...  ...       ...        ...
# 33672  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 33673  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 33674  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 33675  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 33676  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 33677  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 33678  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 33679  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 33680  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 33681  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 33682  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 33683  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 33684  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 33685  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 33686  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 33687  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 33688  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 33689  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 33690  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 33691  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 33692  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 33693  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 33694  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 33695  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 33696  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 33697  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 33698  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 33699  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 33700  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN   NaN  ...       NaN        NaN
# 33701  NaN NaN  NaN NaN NaN NaN  NaN  NaN Na
# 33683  NaN       NaN              NaN      NaN           NaN       NaN NaN
# 33684  NaN       NaN              NaN      NaN           NaN       NaN NaN
# 33685  NaN       NaN              NaN      NaN           NaN       NaN NaN
# 33686  NaN       NaN              NaN      NaN           NaN       NaN NaN
# 33687  NaN       NaN              NaN      NaN           NaN       NaN NaN
# 33688  NaN       NaN              NaN      NaN           NaN       NaN NaN
# 33689  NaN       NaN              NaN      NaN           NaN       NaN NaN
# 33690  NaN       NaN              NaN      NaN           NaN       NaN NaN
# 33691  NaN       NaN              NaN      NaN           NaN       NaN NaN
# 33692  NaN       NaN              NaN      NaN           NaN       NaN NaN
# 33693  NaN       NaN              NaN      NaN           NaN       NaN NaN
# 33694  NaN       NaN              NaN      NaN           NaN       NaN NaN
# 33695  NaN       NaN              NaN      NaN           NaN       NaN NaN
# 33696  NaN       NaN              NaN      NaN           NaN       NaN NaN
# 33697  NaN       NaN              NaN      NaN           NaN       NaN NaN
# 33698  NaN       NaN              NaN      NaN           NaN       NaN NaN
# 33699  NaN       NaN              NaN      NaN           NaN       NaN NaN
# 33700  NaN       NaN              NaN      NaN           NaN       NaN NaN
# 33701  NaN       NaN              NaN      NaN           NaN       NaN NaN
#
#        addressed
# 30           NaN
# 31           NaN
# 32           NaN
# 33           NaN
# 34           NaN
# 35           NaN
# 36           NaN
# 37           NaN
# 38           NaN
# 39           NaN
# 40           NaN
# 41           NaN
# 42           NaN
# 43           NaN
# 44           NaN
# 45           NaN
# 46           NaN
# 47           NaN
# 48           NaN
# 49           NaN
# 50           NaN
# 51           NaN
# 52           NaN
# 53           NaN
# 54           NaN
# 55           NaN
# 56           NaN
# 57           NaN
# 58           NaN
# 59           NaN
# ...          ...
# 33672        NaN
# 33673        NaN
# 33674        NaN
# 33675        NaN
# 33676        NaN
# 33677        NaN
# 33678        NaN
# 33679        NaN
# 33680        NaN
# 33681        NaN
# 33682        NaN
# 33683        NaN
# 33684        NaN
# 33685        NaN
# 33686        NaN
# 33687        NaN
# 33688        NaN
# 33689        NaN
# 33690        NaN
# 33691        NaN
# 33692        NaN
# 33693        NaN
# 33694        NaN
# 33695        NaN
# 33696        NaN
# 33697        NaN
# 33698        NaN
# 33699        NaN
# 33700        NaN
# 33701        NaN
#
# [33672 rows x 3000 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(df,df_spam, train_size = 0.8)
model1 = LinearSVC()
#model1.fit(df.head(20000),df_spam.head(20000))

# %%
#model1.fit(X_train,y_train)
import csv
your_file = "/home/datascience/words.csv"
with open(your_file, "r") as f:
    data = [x for x in csv.reader(f, delimiter='\t')]
with open(your_file, "w") as f:    
    w = csv.writer(f, delimiter=',')
    w.writerows(data)
